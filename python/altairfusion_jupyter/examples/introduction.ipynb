# %% [markdown]
# # Introduction

# %%
import altairfusion_jupyter

# %%
w = altairfusion_jupyter.ExampleWidget()
w
# Out:
# ExampleWidget()

# %%
assert w.value == 'Hello World'

# %%
w.value = "Goodbye"
